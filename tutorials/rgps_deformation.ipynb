# %%
import dataset.RGPS as rgps
from datetime import datetime, timedelta
import config as c

# %%
path = '/cluster/work/users/yingyue/data/RGPS'

t = datetime(2007, 1, 2)
t1 = t + c.OBS_WINDOW_MIN * timedelta(hours=1)
t2 = t + c.OBS_WINDOW_MAX * timedelta(hours=1)

rgps.filename(path, time=t)
# Out:
# '/cluster/work/users/yingyue/data/RGPS/RGPS_2006-12-03_2007-06-01_traj.mat'

# %%
pairs = rgps.get_traj_pairs(path, c.ref_grid, time=t)

# %%
pairs
# Out:
# [[-1008516.2270166335,
#   -1010484.2252407237,
#   -346059.4896625697,
#   -346853.58728277276,
#   datetime.datetime(2006, 12, 4, 16, 12),
#   datetime.datetime(2006, 12, 7, 14, 42, 43, 200000)],
#  [-1010484.2252407237,
#   -1011571.9761712948,
#   -346853.58728277276,
#   -345863.90289091953,
#   datetime.datetime(2006, 12, 7, 14, 42, 43, 200000),
#   datetime.datetime(2006, 12, 10, 14, 55, 40, 800000)],
#  [-1011571.9761712948,
#   -1013055.0239333712,
#   -345863.90289091953,
#   -340425.80041802756,
#   datetime.datetime(2006, 12, 10, 14, 55, 40, 800000),
#   datetime.datetime(2006, 12, 13, 15, 8, 38, 400000)],
#  [-1013055.0239333712,
#   -1015033.2248221519,
#   -340425.80041802756,
#   -346259.622048887,
#   datetime.datetime(2006, 12, 13, 15, 8, 38, 400000),
#   datetime.datetime(2006, 12, 16, 15, 20, 9, 600000)],
#  [-1015033.2248221519,
#   -1015033.2309484346,
#   -346259.622048887,
#   -346358.49839536543,
#   datetime.datetime(2006, 12, 16, 15, 20, 9, 600000),
# ...

# %%
coords_list = []
for d0 in sorted(pairs[])
